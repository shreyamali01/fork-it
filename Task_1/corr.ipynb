# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
import tsfel
import matplotlib.pyplot as plt
import seaborn as sns

# %%
time = 10
offset = 100
folders = ["LAYING","SITTING","STANDING","WALKING","WALKING_DOWNSTAIRS","WALKING_UPSTAIRS"]
classes = {"WALKING":1,"WALKING_UPSTAIRS":2,"WALKING_DOWNSTAIRS":3,"SITTING":4,"STANDING":5,"LAYING":6}

combined_dir = 'D:\\Code\\ML\\fork-it\\Combined'

# %%
X_train=[]
y_train=[]
dataset_dir = os.path.join(combined_dir,"Train")

for folder in folders:
    files = os.listdir(os.path.join(dataset_dir,folder))

    for file in files:

        df = pd.read_csv(os.path.join(dataset_dir,folder,file),sep=",",header=0)
        df = df[offset:offset+time*50]
        X_train.append(df.values)
        y_train.append(classes[folder])

X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_test=[]
y_test=[]
dataset_dir = os.path.join(combined_dir,"Test")

for folder in folders:
    files = os.listdir(os.path.join(dataset_dir,folder))
    for file in files:

        df = pd.read_csv(os.path.join(dataset_dir,folder,file),sep=",",header=0)
        df = df[offset:offset+time*50]
        X_test.append(df.values)
        y_test.append(classes[folder])

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X = np.concatenate((X_train,X_test))
y = np.concatenate((y_train,y_test))

# split the data into training and testing sets. Change the seed value to obtain different random splits.
seed = 4
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=seed,stratify=y)

# %%
cfg_file = tsfel.get_features_by_domain()
tsfel_train_features = tsfel.time_series_features_extractor(cfg_file, X_train, fs=50, header_names=None)
tsfel_test_features = tsfel.time_series_features_extractor(cfg_file, X_test, fs=50, header_names=None)
print(tsfel_train_features.shape)
print(tsfel_test_features.shape)
# Out:
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='126'
#                   max='126',
#                   style='width: 25%',
#               >
#                   126
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='54'
#                   max='54',
#                   style='width: 25%',
#               >
#                   54
#               </progress>
# *** Feature extraction finished ***
# (126, 1152)
# (54, 1152)

# %%
#paths to test data and training data
train_folder = 'D:\\Code\\ML\\fork-it\\Task3\\Dataset_561.csv'
test_folder = 'D:\\Code\\ML\\fork-it\\Task3\\TestDataset_561.csv'
#loading train and test dataset
df_train = pd.read_csv(train_folder)
df_test = pd.read_csv(test_folder)

#seperating features for training and test
dataset_train_features = df_train.iloc[:,:-2] #all columns except last two
dataset_test_features = df_test.iloc[:,:-2] #all columns except last two

# %%
#combining tsfel and dataset features for training and test data
train_features_df = pd.concat([tsfel_train_features, dataset_train_features], axis=1)
test_features_df = pd.concat([tsfel_test_features, dataset_test_features], axis=1)

# %%
#computing correlation matrix
correlation_matrix = train_features_df.corr()

# %%
threshold = 0.9
highly_correlated = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            feature1 = correlation_matrix.columns[i]
            feature2 = correlation_matrix.columns[j]
            highly_correlated.append((feature1, feature2, correlation_matrix.iloc[i, j]))

# Print highly correlated features
print("Highly correlated features:")
for feature1, feature2, corr_value in highly_correlated:
    print(f"{feature1} and {feature2} with correlation coefficient {corr_value:.2f}")

# Detect redundant features
redundant_features = set()
for feature1, feature2, _ in highly_correlated:
    redundant_features.add(feature1)
    redundant_features.add(feature2)

print("\nRedundant features:")
print(redundant_features)
# Out:
# Highly correlated features:
# 0_Area under the curve and 0_Absolute energy with correlation coefficient 0.98
# 0_Average power and 0_Absolute energy with correlation coefficient 1.00
# 0_Average power and 0_Area under the curve with correlation coefficient 0.98
# 0_ECDF Percentile_0 and 0_Area under the curve with correlation coefficient 0.93
# 0_ECDF Percentile_1 and 0_Absolute energy with correlation coefficient 0.97
# 0_ECDF Percentile_1 and 0_Area under the curve with correlation coefficient 0.96
# 0_ECDF Percentile_1 and 0_Average power with correlation coefficient 0.97
# 0_FFT mean coefficient_2 and 0_FFT mean coefficient_1 with correlation coefficient 0.90
# 0_FFT mean coefficient_209 and 0_FFT mean coefficient_208 with correlation coefficient 0.93
# 0_FFT mean coefficient_211 and 0_FFT mean coefficient_208 with correlation coefficient 0.91
# 0_FFT mean coefficient_211 and 0_FFT mean coefficient_210 with correlation coefficient 0.96
# 0_FFT mean coefficient_212 and 0_FFT mean coefficient_208 with correlation coefficient 0.90
# 0_FFT mean coefficient_212 and 0_FFT mean coefficient_209 with correlation coefficient 0.92
# 0_FFT mean coefficient_212 and 0_FFT mean coefficient_210 with correlation coefficient 0.98
# 0_FFT mean coefficient_212 and 0_FFT mean coefficient_211 with correlation coefficient 0.96
# 0_FFT mean coefficient_213 and 0_FFT mean coefficient_209 with correlation coefficient 0.95
# 0_FFT mean coefficient_213 and 0_FFT mean coefficient_212 with correlation coefficient 0.94
# 0_FFT mean coefficient_214 and 0_FFT mean coefficient_208 with correlation coefficient 0.95
# 0_FFT mean coefficient_214 and 0_FFT mean coefficient_209 with correlation coefficient 0.93
# 0_FFT mean coefficient_214 and 0_FFT mean coefficient_210 with correlation coefficient 0.93
# 0_FFT mean coefficient_214 and 0_FFT mean coefficient_211 with correlation coefficient 0.98
# 0_FFT mean coefficient_214 and 0_FFT mean coefficient_212 with correlation coefficient 0.96
# 0_FFT mean coefficient_215 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_215 and 0_FFT mean coefficient_211 with correlation coefficient 0.97
# 0_FFT mean coefficient_215 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_215 and 0_FFT mean coefficient_214 with correlation coefficient 0.94
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_208 with correlation coefficient 0.95
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_209 with correlation coefficient 0.96
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_210 with correlation coefficient 0.93
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_211 with correlation coefficient 0.94
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_213 with correlation coefficient 0.96
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_214 with correlation coefficient 0.98
# 0_FFT mean coefficient_216 and 0_FFT mean coefficient_215 with correlation coefficient 0.92
# 0_FFT mean coefficient_217 and 0_FFT mean coefficient_208 with correlation coefficient 0.91
# 0_FFT mean coefficient_217 and 0_FFT mean coefficient_209 with correlation coefficient 0.94
# 0_FFT mean coefficient_217 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_217 and 0_FFT mean coefficient_216 with correlation coefficient 0.95
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_211 with correlation coefficient 0.96
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_214 with correlation coefficient 0.94
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_218 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_210 with correlation coefficient 0.97
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_211 with correlation coefficient 1.00
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_214 with correlation coefficient 0.99
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_215 with correlation coefficient 0.98
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_216 with correlation coefficient 0.96
# 0_FFT mean coefficient_219 and 0_FFT mean coefficient_218 with correlation coefficient 0.97
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_208 with correlation coefficient 0.93
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_209 with correlation coefficient 0.95
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_210 with correlation coefficient 0.93
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_211 with correlation coefficient 0.95
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_213 with correlation coefficient 0.95
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_214 with correlation coefficient 0.98
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_215 with correlation coefficient 0.91
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_216 with correlation coefficient 0.99
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_217 with correlation coefficient 0.94
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_218 with correlation coefficient 0.93
# 0_FFT mean coefficient_220 and 0_FFT mean coefficient_219 with correlation coefficient 0.96
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_210 with correlation coefficient 0.92
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_212 with correlation coefficient 0.96
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_213 with correlation coefficient 0.96
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_218 with correlation coefficient 0.93
# 0_FFT mean coefficient_221 and 0_FFT mean coefficient_220 with correlation coefficient 0.94
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_208 with correlation coefficient 0.93
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_209 with correlation coefficient 0.91
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_210 with correlation coefficient 0.95
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_214 with correlation coefficient 1.00
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_215 with correlation coefficient 0.95
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_216 with correlation coefficient 0.97
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_218 with correlation coefficient 0.95
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_219 with correlation coefficient 1.00
# 0_FFT mean coefficient_222 and 0_FFT mean coefficient_220 with correlation coefficient 0.97
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_214 with correlation coefficient 0.97
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_215 with correlation coefficient 0.99
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_218 with correlation coefficient 0.99
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_219 with correlation coefficient 0.99
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_220 with correlation coefficient 0.94
# 0_FFT mean coefficient_223 and 0_FFT mean coefficient_222 with correlation coefficient 0.98
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_208 with correlation coefficient 0.90
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_209 with correlation coefficient 0.93
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_210 with correlation coefficient 0.95
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_211 with correlation coefficient 0.92
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_213 with correlation coefficient 0.97
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_214 with correlation coefficient 0.93
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_215 with correlation coefficient 0.93
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_216 with correlation coefficient 0.98
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_217 with correlation coefficient 0.90
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_218 with correlation coefficient 0.96
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_219 with correlation coefficient 0.93
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_220 with correlation coefficient 0.97
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_221 with correlation coefficient 0.99
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_222 with correlation coefficient 0.94
# 0_FFT mean coefficient_224 and 0_FFT mean coefficient_223 with correlation coefficient 0.94
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_209 with correlation coefficient 0.94
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_213 with correlation coefficient 0.93
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_214 with correlation coefficient 0.92
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_216 with correlation coefficient 0.95
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_217 with correlation coefficient 1.00
# 0_FFT mean coefficient_225 and 0_FFT mean coefficient_220 with correlation coefficient 0.95
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_211 with correlation coefficient 0.97
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_214 with correlation coefficient 0.95
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_218 with correlation coefficient 1.00
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_219 with correlation coefficient 0.98
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_220 with correlation coefficient 0.93
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_221 with correlation coefficient 0.91
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_222 with correlation coefficient 0.97
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_223 with correlation coefficient 1.00
# 0_FFT mean coefficient_226 and 0_FFT mean coefficient_224 with correlation coefficient 0.95
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_208 with correlation coefficient 0.91
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_210 with correlation coefficient 0.98
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_214 with correlation coefficient 0.97
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_215 with correlation coefficient 0.99
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_216 with correlation coefficient 0.96
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_218 with correlation coefficient 0.99
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_219 with correlation coefficient 0.99
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_220 with correlation coefficient 0.95
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_222 with correlation coefficient 0.98
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_223 with correlation coefficient 1.00
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_224 with correlation coefficient 0.95
# 0_FFT mean coefficient_227 and 0_FFT mean coefficient_226 with correlation coefficient 1.00
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_209 with correlation coefficient 0.94
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_212 with correlation coefficient 0.90
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_214 with correlation coefficient 0.94
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_216 with correlation coefficient 0.97
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_217 with correlation coefficient 0.99
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_220 with correlation coefficient 0.97
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_222 with correlation coefficient 0.93
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_224 with correlation coefficient 0.92
# 0_FFT mean coefficient_228 and 0_FFT mean coefficient_225 with correlation coefficient 1.00
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_210 with correlation coefficient 0.95
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_213 with correlation coefficient 0.95
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_215 with correlation coefficient 0.93
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_216 with correlation coefficient 0.95
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_218 with correlation coefficient 0.95
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_219 with correlation coefficient 0.91
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_220 with correlation coefficient 0.95
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_221 with correlation coefficient 1.00
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_222 with correlation coefficient 0.91
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_223 with correlation coefficient 0.93
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_224 with correlation coefficient 0.99
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_226 with correlation coefficient 0.94
# 0_FFT mean coefficient_229 and 0_FFT mean coefficient_227 with correlation coefficient 0.93
# 0_FFT mean coefficient_23 and 0_FFT mean coefficient_22 with correlation coefficient 0.97
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_208 with correlation coefficient 0.91
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_210 with correlation coefficient 0.98
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_214 with correlation coefficient 0.98
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_215 with correlation coefficient 0.98
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_216 with correlation coefficient 0.96
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_218 with correlation coefficient 0.98
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_219 with correlation coefficient 1.00
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_220 with correlation coefficient 0.96
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_222 with correlation coefficient 0.99
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_223 with correlation coefficient 1.00
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_226 with correlation coefficient 0.99
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_227 with correlation coefficient 1.00
# 0_FFT mean coefficient_230 and 0_FFT mean coefficient_229 with correlation coefficient 0.92
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_210 with correlation coefficient 0.97
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_214 with correlation coefficient 0.99
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_215 with correlation coefficient 0.97
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_216 with correlation coefficient 0.96
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_218 with correlation coefficient 0.97
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_219 with correlation coefficient 1.00
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_220 with correlation coefficient 0.97
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_222 with correlation coefficient 1.00
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_223 with correlation coefficient 0.99
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_226 with correlation coefficient 0.98
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_227 with correlation coefficient 0.99
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_229 with correlation coefficient 0.92
# 0_FFT mean coefficient_231 and 0_FFT mean coefficient_230 with correlation coefficient 1.00
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_210 with correlation coefficient 0.93
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_212 with correlation coefficient 0.96
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_213 with correlation coefficient 0.95
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_215 with correlation coefficient 0.91
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_218 with correlation coefficient 0.94
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_220 with correlation coefficient 0.94
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_221 with correlation coefficient 1.00
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_223 with correlation coefficient 0.91
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_224 with correlation coefficient 0.99
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_226 with correlation coefficient 0.92
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_227 with correlation coefficient 0.91
# 0_FFT mean coefficient_232 and 0_FFT mean coefficient_229 with correlation coefficient 1.00
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_208 with correlation coefficient 0.93
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_209 with correlation coefficient 0.95
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_211 with correlation coefficient 0.90
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_212 with correlation coefficient 0.93
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_214 with correlation coefficient 0.96
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_216 with correlation coefficient 0.98
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_217 with correlation coefficient 0.98
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_219 with correlation coefficient 0.92
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_220 with correlation coefficient 0.99
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_222 with correlation coefficient 0.95
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_225 with correlation coefficient 0.99
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_227 with correlation coefficient 0.90
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_228 with correlation coefficient 1.00
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_229 with correlation coefficient 0.90
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_230 with correlation coefficient 0.92
# 0_FFT mean coefficient_233 and 0_FFT mean coefficient_231 with correlation coefficient 0.93
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_208 with correlation coefficient 0.91
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_210 with correlation coefficient 0.98
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_214 with correlation coefficient 0.98
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_215 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_216 with correlation coefficient 0.95
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_218 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_219 with correlation coefficient 1.00
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_220 with correlation coefficient 0.95
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_222 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_223 with correlation coefficient 1.00
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_226 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_227 with correlation coefficient 1.00
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_229 with correlation coefficient 0.92
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_230 with correlation coefficient 1.00
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_231 with correlation coefficient 0.99
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_232 with correlation coefficient 0.90
# 0_FFT mean coefficient_234 and 0_FFT mean coefficient_233 with correlation coefficient 0.90
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_211 with correlation coefficient 0.97
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_214 with correlation coefficient 0.95
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_218 with correlation coefficient 1.00
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_219 with correlation coefficient 0.98
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_220 with correlation coefficient 0.93
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_221 with correlation coefficient 0.91
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_222 with correlation coefficient 0.96
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_223 with correlation coefficient 0.99
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_224 with correlation coefficient 0.95
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_226 with correlation coefficient 1.00
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_227 with correlation coefficient 0.99
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_229 with correlation coefficient 0.95
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_230 with correlation coefficient 0.98
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_231 with correlation coefficient 0.98
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_232 with correlation coefficient 0.93
# 0_FFT mean coefficient_235 and 0_FFT mean coefficient_234 with correlation coefficient 0.99
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_209 with correlation coefficient 0.92
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_213 with correlation coefficient 0.92
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_216 with correlation coefficient 0.93
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_217 with correlation coefficient 1.00
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_220 with correlation coefficient 0.93
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_225 with correlation coefficient 1.00
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_228 with correlation coefficient 0.99
# 0_FFT mean coefficient_236 and 0_FFT mean coefficient_233 with correlation coefficient 0.98
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_209 with correlation coefficient 0.94
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_210 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_211 with correlation coefficient 0.93
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_212 with correlation coefficient 0.99
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_213 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_214 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_215 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_216 with correlation coefficient 0.99
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_217 with correlation coefficient 0.91
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_218 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_219 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_220 with correlation coefficient 0.98
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_221 with correlation coefficient 0.97
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_222 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_223 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_224 with correlation coefficient 1.00
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_225 with correlation coefficient 0.91
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_226 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_227 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_228 with correlation coefficient 0.93
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_229 with correlation coefficient 0.99
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_230 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_231 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_232 with correlation coefficient 0.98
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_233 with correlation coefficient 0.95
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_234 with correlation coefficient 0.96
# 0_FFT mean coefficient_237 and 0_FFT mean coefficient_235 with correlation coefficient 0.96
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_211 with correlation coefficient 0.98
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_214 with correlation coefficient 0.96
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_218 with correlation coefficient 0.99
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_219 with correlation coefficient 0.99
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_220 with correlation coefficient 0.93
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_222 with correlation coefficient 0.97
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_223 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_226 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_227 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_229 with correlation coefficient 0.92
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_230 with correlation coefficient 0.99
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_231 with correlation coefficient 0.99
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_232 with correlation coefficient 0.90
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_234 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_235 with correlation coefficient 1.00
# 0_FFT mean coefficient_238 and 0_FFT mean coefficient_237 with correlation coefficient 0.95
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_208 with correlation coefficient 0.93
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_209 with correlation coefficient 0.91
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_210 with correlation coefficient 0.95
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_211 with correlation coefficient 0.98
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_214 with correlation coefficient 1.00
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_215 with correlation coefficient 0.95
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_216 with correlation coefficient 0.97
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_218 with correlation coefficient 0.94
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_219 with correlation coefficient 0.99
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_220 with correlation coefficient 0.98
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_222 with correlation coefficient 1.00
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_223 with correlation coefficient 0.97
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_224 with correlation coefficient 0.94
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_225 with correlation coefficient 0.91
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_226 with correlation coefficient 0.96
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_227 with correlation coefficient 0.98
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_228 with correlation coefficient 0.94
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_229 with correlation coefficient 0.90
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_230 with correlation coefficient 0.99
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_231 with correlation coefficient 0.99
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_233 with correlation coefficient 0.96
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_234 with correlation coefficient 0.98
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_235 with correlation coefficient 0.95
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_237 with correlation coefficient 0.95
# 0_FFT mean coefficient_239 and 0_FFT mean coefficient_238 with correlation coefficient 0.97
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_210 with correlation coefficient 0.90
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_212 with correlation coefficient 0.94
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_213 with correlation coefficient 0.96
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_216 with correlation coefficient 0.93
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_220 with correlation coefficient 0.94
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_221 with correlation coefficient 1.00
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_224 with correlation coefficient 0.98
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_229 with correlation coefficient 0.99
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_232 with correlation coefficient 0.99
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_233 with correlation coefficient 0.91
# 0_FFT mean coefficient_240 and 0_FFT mean coefficient_237 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_209 with correlation coefficient 0.94
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_210 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_211 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_212 with correlation coefficient 0.99
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_214 with correlation coefficient 0.98
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_215 with correlation coefficient 0.94
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_216 with correlation coefficient 0.99
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_217 with correlation coefficient 0.92
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_218 with correlation coefficient 0.95
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_219 with correlation coefficient 0.97
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_220 with correlation coefficient 1.00
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_221 with correlation coefficient 0.95
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_222 with correlation coefficient 0.98
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_223 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_224 with correlation coefficient 0.98
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_225 with correlation coefficient 0.93
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_226 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_227 with correlation coefficient 0.97
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_228 with correlation coefficient 0.95
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_229 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_230 with correlation coefficient 0.97
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_231 with correlation coefficient 0.98
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_232 with correlation coefficient 0.95
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_233 with correlation coefficient 0.97
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_234 with correlation coefficient 0.97
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_235 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_236 with correlation coefficient 0.91
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_237 with correlation coefficient 0.99
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_238 with correlation coefficient 0.96
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_239 with correlation coefficient 0.98
# 0_FFT mean coefficient_241 and 0_FFT mean coefficient_240 with correlation coefficient 0.94
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_208 with correlation coefficient 0.92
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_210 with correlation coefficient 0.97
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_211 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_214 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_215 with correlation coefficient 0.97
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_216 with correlation coefficient 0.95
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_218 with correlation coefficient 0.97
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_219 with correlation coefficient 1.00
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_220 with correlation coefficient 0.96
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_222 with correlation coefficient 1.00
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_223 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_224 with correlation coefficient 0.93
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_226 with correlation coefficient 0.98
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_227 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_229 with correlation coefficient 0.90
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_230 with correlation coefficient 1.00
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_231 with correlation coefficient 1.00
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_233 with correlation coefficient 0.92
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_234 with correlation coefficient 1.00
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_235 with correlation coefficient 0.98
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_237 with correlation coefficient 0.95
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_238 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_239 with correlation coefficient 0.99
# 0_FFT mean coefficient_242 and 0_FFT mean coefficient_241 with correlation coefficient 0.97
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_210 with correlation coefficient 0.99
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_211 with correlation coefficient 0.96
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_214 with correlation coefficient 0.94
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_216 with correlation coefficient 0.94
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_218 with correlation coefficient 1.00
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_219 with correlation coefficient 0.97
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_220 with correlation coefficient 0.93
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_221 with correlation coefficient 0.93
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_222 with correlation coefficient 0.95
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_223 with correlation coefficient 0.99
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_224 with correlation coefficient 0.96
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_226 with correlation coefficient 1.00
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_227 with correlation coefficient 0.99
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_229 with correlation coefficient 0.96
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_230 with correlation coefficient 0.98
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_231 with correlation coefficient 0.97
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_232 with correlation coefficient 0.94
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_234 with correlation coefficient 0.99
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_235 with correlation coefficient 1.00
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_237 with correlation coefficient 0.97
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_238 with correlation coefficient 0.99
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_239 with correlation coefficient 0.95
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_240 with correlation coefficient 0.90
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_241 with correlation coefficient 0.96
# 0_FFT mean coefficient_243 and 0_FFT mean coefficient_242 with correlation coefficient 0.97
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_209 with correlation coefficient 0.93
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_216 with correlation coefficient 0.93
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_217 with correlation coefficient 1.00
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_220 with correlation coefficient 0.94
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_225 with correlation coefficient 0.99
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_228 with correlation coefficient 0.99
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_233 with correlation coefficient 0.97
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_236 with correlation coefficient 1.00
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_237 with correlation coefficient 0.90
# 0_FFT mean coefficient_244 and 0_FFT mean coefficient_241 with correlation coefficient 0.91
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_208 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_209 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_210 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_211 with correlation coefficient 0.96
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_212 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_213 with correlation coefficient 0.94
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_214 with correlation coefficient 0.99
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_215 with correlation coefficient 0.94
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_216 with correlation coefficient 1.00
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_217 with correlation coefficient 0.93
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_218 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_219 with correlation coefficient 0.97
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_220 with correlation coefficient 0.99
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_221 with correlation coefficient 0.93
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_222 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_223 with correlation coefficient 0.96
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_224 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_225 with correlation coefficient 0.94
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_226 with correlation coefficient 0.96
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_227 with correlation coefficient 0.97
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_228 with correlation coefficient 0.96
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_229 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_230 with correlation coefficient 0.97
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_231 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_232 with correlation coefficient 0.93
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_233 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_234 with correlation coefficient 0.97
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_235 with correlation coefficient 0.96
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_236 with correlation coefficient 0.92
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_237 with correlation coefficient 0.99
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_238 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_239 with correlation coefficient 0.98
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_240 with correlation coefficient 0.92
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_241 with correlation coefficient 0.99
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_242 with correlation coefficient 0.97
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_243 with correlation coefficient 0.95
# 0_FFT mean coefficient_245 and 0_FFT mean coefficient_244 with correlation coefficient 0.92
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_210 with correlation coefficient 0.98
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_211 with correlation coefficient 0.97
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_212 with correlation coefficient 0.97
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_214 with correlation coefficient 0.94
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_215 with correlation coefficient 1.00
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_216 with correlation coefficient 0.92
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_218 with correlation coefficient 1.00
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_219 with correlation coefficient 0.98
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_220 with correlation coefficient 0.91
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_222 with correlation coefficient 0.95
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_223 with correlation coefficient 0.99
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_224 with correlation coefficient 0.93
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_226 with correlation coefficient 1.00
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_227 with correlation coefficient 0.99
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_229 with correlation coefficient 0.92
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_230 with correlation coefficient 0.98
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_231 with correlation coefficient 0.97
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_232 with correlation coefficient 0.90
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_234 with correlation coefficient 0.99
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_235 with correlation coefficient 1.00
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_237 with correlation coefficient 0.94
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_238 with correlation coefficient 1.00
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_239 with correlation coefficient 0.95
# 0_FFT mean coefficient_246 and 0_FFT mean coefficient_241 with correlation coefficient 0.94
# ...
# fBodyBodyGyroJerkMag-iqr() and fBodyGyro-iqr()-Y with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyAccJerkMag-mean() with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyAccJerkMag-sma() with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroMag-mean() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroMag-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroMag-iqr() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroJerkMag-mean() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroJerkMag-std() with correlation coefficient 0.96
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroJerkMag-mad() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroJerkMag-max() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-iqr() and fBodyBodyGyroJerkMag-sma() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-std()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-std()-Y with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-std()-Z with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-mad()-X with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-mad()-Y with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-mad()-Z with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-max()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-max()-Y with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-min()-X with correlation coefficient -0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-min()-Y with correlation coefficient -0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAcc-iqr()-Y with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-std()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-std()-Y with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-mad()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-mad()-Y with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-min()-X with correlation coefficient -0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-iqr()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-iqr()-Y with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-entropy()-X with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-entropy()-Y with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerk-entropy()-Z with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and tBodyGyro-std()-Z with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and tBodyGyro-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-std()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-std()-Z with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-mad()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-mad()-Z with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-sma() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-iqr()-Z with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-entropy()-X with correlation coefficient 0.96
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-entropy()-Y with correlation coefficient 0.96
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerk-entropy()-Z with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-mean() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-std() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-mad() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-max() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAccMag-entropy() with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-mean() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-std() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-mad() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-max() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tGravityAccMag-entropy() with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-mean() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-std() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-mad() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-max() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-iqr() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyAccJerkMag-entropy() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-mean() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-std() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-mad() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-max() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroMag-iqr() with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerkMag-mean() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerkMag-sma() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and tBodyGyroJerkMag-entropy() with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mean()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mean()-Y with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mean()-Z with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-std()-Y with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mad()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mad()-Y with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-mad()-Z with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-sma() with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-iqr()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-iqr()-Y with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-entropy()-X with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-entropy()-Y with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAcc-entropy()-Z with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-mean()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-mean()-Y with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-std()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-std()-Y with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-mad()-X with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-mad()-Y with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-sma() with correlation coefficient 0.94
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-iqr()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-iqr()-Y with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-entropy()-X with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-entropy()-Y with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAccJerk-entropy()-Z with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mean()-X with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mean()-Y with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mean()-Z with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mad()-X with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mad()-Y with correlation coefficient 0.90
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-mad()-Z with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-sma() with correlation coefficient 0.95
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-entropy()-X with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-entropy()-Y with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and fBodyGyro-entropy()-Z with correlation coefficient 0.97
# fBodyBodyGyroJerkMag-entropy() and fBodyAccMag-mean() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyAccMag-mad() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyAccMag-sma() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyAccMag-entropy() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-mean() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-std() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-mad() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-sma() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-iqr() with correlation coefficient 0.92
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyAccJerkMag-entropy() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyGyroMag-mean() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyGyroMag-mad() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyGyroMag-sma() with correlation coefficient 0.93
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyGyroMag-iqr() with correlation coefficient 0.91
# fBodyBodyGyroJerkMag-entropy() and fBodyBodyGyroMag-entropy() with correlation coefficient 0.98
# fBodyBodyGyroJerkMag-kurtosis() and fBodyBodyGyroJerkMag-skewness() with correlation coefficient 0.97
# angle(X,gravityMean) and tGravityAcc-mean()-X with correlation coefficient -0.99
# angle(X,gravityMean) and tGravityAcc-max()-X with correlation coefficient -0.99
# angle(X,gravityMean) and tGravityAcc-min()-X with correlation coefficient -0.99
# angle(X,gravityMean) and tGravityAcc-energy()-X with correlation coefficient -0.99
# angle(Y,gravityMean) and tGravityAcc-mean()-Y with correlation coefficient -0.99
# angle(Y,gravityMean) and tGravityAcc-max()-Y with correlation coefficient -0.99
# angle(Y,gravityMean) and tGravityAcc-min()-Y with correlation coefficient -0.99
# angle(Z,gravityMean) and tGravityAcc-mean()-Z with correlation coefficient -1.00
# angle(Z,gravityMean) and tGravityAcc-max()-Z with correlation coefficient -0.99
# angle(Z,gravityMean) and tGravityAcc-min()-Z with correlation coefficient -0.99
#
# Redundant features:
# {'0_FFT mean coefficient_225', '2_Root mean square', '2_FFT mean coefficient_238', 'fBodyAcc-iqr()-X', '2_Wavelet energy_0', '1_FFT mean coefficient_247', 'fBodyBodyGyroJerkMag-mad()', '1_Spectral spread', '2_Spectral kurtosis', '1_Wavelet standard deviation_5', 'tBodyAccJerk-max()-X', 'fBodyGyro-kurtosis()-Z', '2_Wavelet standard deviation_7', '2_Wavelet variance_1', 'tGravityAcc-arCoeff()-X,4', 'tBodyGyroJerk-std()-X', '0_Standard deviation', '1_Wavelet variance_1', '1_FFT mean coefficient_242', '0_Wavelet variance_0', '2_FFT mean coefficient_235', 'fBodyAcc-bandsEnergy()-17,32.1', 'tBodyAcc-min()-Z', '1_Wavelet standard deviation_3', 'fBodyAccJerk-iqr()-Z', '1_Wavelet energy_5', 'tBodyAccJerk-arCoeff()-Y,1', '1_LPCC_6', '1_FFT mean coefficient_220', 'tBodyAccJerk-energy()-X', '2_FFT mean coefficient_243', '0_FFT mean coefficient_233', 'tBodyAcc-entropy()-Y', 'fBodyAccJerk-bandsEnergy()-25,32.1', '2_FFT mean coefficient_5', '0_Wavelet absolute mean_4', 'fBodyGyro-energy()-X', '0_FFT mean coefficient_57', '2_FFT mean coefficient_233', '0_FFT mean coefficient_227', 'tGravityAcc-arCoeff()-Z,1', '1_Spectral centroid', 'tBodyAcc-std()-Z', 'fBodyAcc-mean()-Z', 'fBodyAcc-mean()-X', '1_Wavelet variance_5', 'fBodyAcc-bandsEnergy()-49,56.2', '0_FFT mean coefficient_23', '0_FFT mean coefficient_246', 'tBodyAccJerkMag-sma()', '1_Wavelet variance_3', '2_LPCC_1', 'tBodyGyroMag-arCoeff()1', '1_FFT mean coefficient_210', '0_FFT mean coefficient_216', '2_LPCC_9', 'tBodyGyro-max()-Z', '0_FFT mean coefficient_1', '2_FFT mean coefficient_249', 'fBodyAccJerk-bandsEnergy()-33,48.1', '1_FFT mean coefficient_219', 'tGravityAcc-arCoeff()-X,1', 'fBodyBodyGyroJerkMag-entropy()', 'tBodyGyro-arCoeff()-X,1', 'fBodyAccJerk-kurtosis()-Y', '2_Mean absolute deviation', 'fBodyAccJerk-iqr()-Y', '0_FFT mean coefficient_236', '1_FFT mean coefficient_227', '2_Wavelet absolute mean_2', '0_FFT mean coefficient_210', 'fBodyAccJerk-mean()-Y', 'fBodyAccJerk-std()-X', 'tGravityAcc-std()-X', '0_Negative turning points', '0_Maximum frequency', '1_Wavelet standard deviation_0', 'tBodyGyroMag-std()', '0_Spectral skewness', '0_Wavelet variance_7', '1_FFT mean coefficient_239', 'fBodyAccJerk-meanFreq()-Z', 'fBodyAcc-bandsEnergy()-1,8.1', '0_FFT mean coefficient_211', 'tBodyGyroJerk-iqr()-Y', '2_Wavelet absolute mean_1', '0_FFT mean coefficient_234', '1_Spectral roll-off', '1_Spectral skewness', 'fBodyGyro-bandsEnergy()-1,24', '0_Wavelet absolute mean_6', '1_Root mean square', '1_Wavelet energy_7', '1_Spectral slope', '2_FFT mean coefficient_216', 'fBodyAcc-bandsEnergy()-33,48.2', 'fBodyBodyAccJerkMag-sma()', '0_FFT mean coefficient_11', 'tGravityAcc-arCoeff()-X,2', 'fBodyBodyGyroMag-iqr()', '2_FFT mean coefficient_214', '2_Wavelet energy_2', 'fBodyBodyGyroJerkMag-iqr()', 'fBodyAcc-bandsEnergy()-17,24.2', 'fBodyGyro-mean()-X', 'tBodyAccJerk-max()-Y', '0_Wavelet energy_3', 'tBodyAccJerk-min()-Y', 'tBodyGyro-iqr()-Z', 'fBodyAccJerk-bandsEnergy()-1,24.1', 'fBodyBodyGyroJerkMag-kurtosis()', '1_Wavelet variance_2', '2_Spectral roll-off', '2_Peak to peak distance', 'tBodyGyroJerk-mad()-Y', '2_FFT mean coefficient_245', 'tBodyGyroJerk-min()-X', '2_FFT mean coefficient_219', 'tBodyGyroJerk-entropy()-X', 'fBodyAcc-bandsEnergy()-1,16.2', '1_LPCC_0', '2_FFT mean coefficient_247', '1_LPCC_8', '1_Wavelet absolute mean_7', 'tBodyAcc-min()-Y', 'fBodyGyro-iqr()-X', '1_Wavelet standard deviation_8', '1_Wavelet absolute mean_1', '1_Wavelet standard deviation_4', '0_Mean', '0_FFT mean coefficient_238', '1_LPCC_11', '2_Wavelet absolute mean_6', 'tGravityAcc-std()-Z', '1_FFT mean coefficient_232', '2_MFCC_3', 'fBodyAcc-sma()', 'tBodyAcc-energy()-Z', 'fBodyBodyGyroMag-max()', 'fBodyAccJerk-bandsEnergy()-17,32.1', 'fBodyAcc-mad()-X', '0_FFT mean coefficient_242', '2_FFT mean coefficient_250', 'tBodyAccJerk-std()-X', '2_Wavelet energy_4', '1_Wavelet standard deviation_1', '2_LPCC_8', 'fBodyGyro-entropy()-X', 'tBodyGyroJerkMag-iqr()', 'tBodyGyroJerk-std()-Y', 'tBodyGyro-arCoeff()-Y,2', 'tGravityAccMa ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.title("Correlation Matrix")
plt.show()
